# %%
True
# Out:
# True

# %% [markdown]
# # NLP Exercises
#
# Exercises from Daniel Jurafsky and James H. Martin, _Speech and Language Processing: An Introduction to Natural Language Processing, Computational Linguistics, and Speech Recognition_, 3rd Edition, [online manuscript](https://web.stanford.edu/~jurafsky/slp3/) released 6 January 2026.
#
# ## Part I: Large Language Models
#
# ### Chapter 4: Logistic Regression and Text Classification
